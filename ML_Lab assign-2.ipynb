# %%
#A1,A2,A3
import pandas as pd
import numpy as np

df = pd.read_excel(r"C:\Users\Surya\OneDrive\Desktop\lab2\Lab Session Data.xlsx")

print(" DataFrame:")
print(df)

df1 = df.iloc[:, 1:4]
print("\nDataFrame after slicing columns 1 to 3:")
print(df1)

df2 = df.iloc[:, 4]
print("\nSeries after slicing column 4:")
print(df2)

matrix = df1.values

rank = np.linalg.matrix_rank(matrix)
print("\nRank of the matrix df1:", rank)

r = df.shape[0]
print("Number of rows in the original DataFrame:", r)

d1 = pd.DataFrame(df2)
m = d1.values

rank1 = np.linalg.matrix_rank(m)
print("Rank of the matrix df2:", rank1)

t1 = np.linalg.pinv(matrix)
print("\nPseudoinverse of df1:")
print(t1)

# here we converyt in 2d array before we do pseudi inverse
m2 = d1.values.reshape(-1, 1)
t2 = np.linalg.pinv(m2)
print("\nPseudoinverse of df2 (reshaped):")
print(t2)


#cost is

print(t1 @ df2)

df['Customer_Class'] = df['Payment (Rs)'].apply(lambda x: 'RICH' if x > 200 else 'POOR')
(df)
# Out:
#  DataFrame:
#   Customer  Candies (#)  Mangoes (Kg)  Milk Packets (#)  Payment (Rs)  \
# 0      C_1           20             6                 2           386
# 1      C_2           16             3                 6           289
# 2      C_3           27             6                 2           393
# 3      C_4           19             1                 2           110
# 4      C_5           24             4                 2           280
# 5      C_6           22             1                 5           167
# 6      C_7           15             4                 2           271
# 7      C_8           18             4                 2           274
# 8      C_9           21             1                 4           148
# 9     C_10           16             2                 4           198
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
# ...

# %%
#A4
import pandas as pd
import numpy as np

df = pd.read_excel(r"C:\Users\Surya\OneDrive\Desktop\lab2\Lab Session Data.xlsx")

print(" DataFrame:")
print(df)

df1 = df.iloc[:, 1:4]
print("\nDataFrame after slicing columns 1 to 3:")
print(df1)

df2 = df.iloc[:, 4]
print("\nSeries after slicing column 4:")
print(df2)

matrix = df1.values

rank = np.linalg.matrix_rank(matrix)
print("\nRank of the matrix df1:", rank)

r = df.shape[0]
print("Number of rows in the original DataFrame:", r)

d1 = pd.DataFrame(df2)
m = d1.values

rank1 = np.linalg.matrix_rank(m)
print("Rank of the matrix df2:", rank1)

t1 = np.linalg.pinv(matrix)
print("\nPseudoinverse of df1:")
print(t1)

# here we converyt in 2d array before we do pseudi inverse
m2 = d1.values.reshape(-1, 1)
t2 = np.linalg.pinv(m2)
print("\nPseudoinverse of df2 (reshaped):")
print(t2)


#cost is

print(t1 @ df2)

df['Customer_Class'] = df['Payment (Rs)'].apply(lambda x: 'RICH' if x > 200 else 'POOR')
(df)
# Out:
#  DataFrame:
#   Customer  Candies (#)  Mangoes (Kg)  Milk Packets (#)  Payment (Rs)  \
# 0      C_1           20             6                 2           386
# 1      C_2           16             3                 6           289
# 2      C_3           27             6                 2           393
# 3      C_4           19             1                 2           110
# 4      C_5           24             4                 2           280
# 5      C_6           22             1                 5           167
# 6      C_7           15             4                 2           271
# 7      C_8           18             4                 2           274
# 8      C_9           21             1                 4           148
# 9     C_10           16             2                 4           198
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
# ...

# %%
#A5
import pandas as pd
import numpy as np

# Load the thyroid dataset
data_on_thyroid = pd.read_excel(r"C:\Users\Surya\OneDrive\Desktop\lab2\Lab Session Data.xlsx", sheet_name='thyroid0387_UCI')

# Study each attribute and associated values
print("DataFrame Info:")
print(data_on_thyroid.info())

# Identify datatype for each attribute
print("\nData Types:")
print(data_on_thyroid.dtypes)

# Check for missing values
print("\nMissing Values:")
print(data_on_thyroid.isnull().sum())

# Check for outliers in numeric data
numeric_cols = data_on_thyroid.select_dtypes(include=[np.number])
print("\nSummary Statistics for Numeric Data:")
print(numeric_cols.describe())

# Calculate mean and variance for numeric variables
print("\nMean and Variance for Numeric Data:")
for col in numeric_cols.columns:
    mean = numeric_cols[col].mean()
    variance = numeric_cols[col].var()
    print(f"{col}: Mean = {mean}, Variance = {variance}")
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9172 entries, 0 to 9171
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Record ID                  9172 non-null   int64
#  1   age                        9172 non-null   int64
#  2   sex                        9172 non-null   object
#  3   on thyroxine               9172 non-null   object
#  4   query on thyroxine         9172 non-null   object
#  5   on antithyroid medication  9172 non-null   object
#  6   sick                       9172 non-null   object
#  7   pregnant                   9172 non-null   object
#  8   thyroid surgery            9172 non-null   object
#  9   I131 treatment             9172 non-null   object
#  10  query hypothyroid          9172 non-null   object
#  11  query hyperthyroid         9172 non-null   object
#  12  lithium                    9172 non-null   object
# ...

# %%
#A5 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data

thy=pd.read_excel(r"C:\Users\Surya\OneDrive\Desktop\lab2\Lab Session Data.xlsx",sheet_name='thyroid0387_UCI', na_values='?')
print(thy)

# i) Identify the data types of each attribute
print(thy.dtypes)
# ii)
for column in thy.columns:
    print(f"Column: {column}")
    print(f"Unique Values: {thy[column].unique()}")
    print("\n")

# iii)
#thyroid.describe()
numeric_columns = thy.select_dtypes(include=['float64', 'int64']).columns
print(thy[numeric_columns].describe())
#iv) Check for missing values in each column
missing_values = thy.isnull().sum()
print(missing_values)
#v)
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize outliers using boxplots for numeric columns
for column in numeric_columns:
    plt.figure(figsize=(8, 4))
    sns.boxplot(thy[column])
    plt.title(f"Boxplot for {column}")
    plt.show()
#vi)
for column in numeric_columns:
    mean_val = thy[column].mean()
    variance_val = thy[column].var()
    std_dev_val = thy[column].std()

    print(f"Column: {column}")
    print(f"Mean: {mean_val}")
    print(f"Variance: {variance_val}")
    print(f"Standard Deviation: {std_dev_val}")
    print("\n")
# Out:
#       Record ID  age sex on thyroxine query on thyroxine  \
# 0     840801013   29   F            f                  f
# 1     840801014   29   F            f                  f
# 2     840801042   41   F            f                  f
# 3     840803046   36   F            f                  f
# 4     840803047   32   F            f                  f
# ...         ...  ...  ..          ...                ...
# 9167  870119022   56   M            f                  f
# 9168  870119023   22   M            f                  f
# 9169  870119025   69   M            f                  f
# 9170  870119027   47   F            f                  f
# 9171  870119035   31   M            f                  f
#
#      on antithyroid medication sick pregnant thyroid surgery I131 treatment  \
# 0                            f    f        f               f              f
# 1                            f    f        f               f              f
# ...

# %%
#A6
thyroid['Record ID'] = thyroid['Record ID'].fillna(thyroid['Record ID'].mean())

# Impute other numeric columns with median
for col in numeric_columns:
    if col == 'Record ID':
        continue
    thyroid[col] = thyroid[col].fillna(thyroid[col].median())

# Impute categorical columns with mode
categorical_columns = thyroid.select_dtypes(include=['object']).columns
for col in categorical_columns:
    print(categorical_columns)
    thyroid[col] = thyroid[col].fillna(thyroid[col].mode()[0])
# Out:
# Index(['sex', 'on thyroxine', 'query on thyroxine',
#        'on antithyroid medication', 'sick', 'pregnant', 'thyroid surgery',
#        'I131 treatment', 'query hypothyroid', 'query hyperthyroid', 'lithium',
#        'goitre', 'tumor', 'hypopituitary', 'psych', 'TSH measured',
#        'T3 measured', 'TT4 measured', 'T4U measured', 'FTI measured',
#        'TBG measured', 'referral source', 'Condition'],
#       dtype='object')
# Index(['sex', 'on thyroxine', 'query on thyroxine',
#        'on antithyroid medication', 'sick', 'pregnant', 'thyroid surgery',
#        'I131 treatment', 'query hypothyroid', 'query hyperthyroid', 'lithium',
#        'goitre', 'tumor', 'hypopituitary', 'psych', 'TSH measured',
#        'T3 measured', 'TT4 measured', 'T4U measured', 'FTI measured',
#        'TBG measured', 'referral source', 'Condition'],
#       dtype='object')
# Index(['sex', 'on thyroxine', 'query on thyroxine',
# ...

# %%
#A7
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# Load the data
df = pd.read_excel(r"C:\Users\Surya\OneDrive\Desktop\lab2\Lab Session Data.xlsx", sheet_name='thyroid0387_UCI')

# Identify numeric columns
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns

# Display descriptive statistics for numeric columns
print("Descriptive Statistics for Numeric Columns:")
print(df[numeric_columns].describe())
print("\n")

# Assuming 'age' is the column with high standard deviation that needs to be normalized
scaler = StandardScaler()
df['age'] = scaler.fit_transform(df[['age']])

# Display the normalized 'age' column
print("Z-score Normalized 'age' Column:")
print(df['age'])
# Out:
# Descriptive Statistics for Numeric Columns:
#           Record ID           age
# count  9.172000e+03   9172.000000
# mean   8.529473e+08     73.555822
# std    7.581969e+06   1183.976718
# min    8.408010e+08      1.000000
# 25%    8.504090e+08     37.000000
# 50%    8.510040e+08     55.000000
# 75%    8.607110e+08     68.000000
# max    8.701190e+08  65526.000000
#
#
# Z-score Normalized 'age' Column:
# 0      -0.037634
# 1      -0.037634
# 2      -0.027499
# 3      -0.031722
# 4      -0.035100
#           ...
# 9167   -0.014829
# 9168   -0.043547
# 9169   -0.003848
# 9170   -0.022431
# 9171   -0.035945
# Name: age, Length: 9172, dtype: float64

# %%
#A8
import pandas as pd
import numpy as np

# Load the dataset
file_path = r"C:\Users\Surya\OneDrive\Desktop\lab2\Lab Session Data.xlsx"
df = pd.read_excel(file_path, sheet_name='thyroid0387_UCI')

# Replace '?' with NaN for consistent data handling
df.replace('?', np.nan, inplace=True)

# Define the correct binary columns based on the dataset
binary_columns = [
    'on thyroxine', 'query on thyroxine', 'on antithyroid medication',
    'sick', 'pregnant', 'thyroid surgery', 'I131 treatment',
    'query hypothyroid', 'query hyperthyroid', 'lithium', 
    'goitre', 'tumor', 'hypopituitary', 'psych', 'TSH measured'
]

# Check if all specified columns exist in the DataFrame
missing_cols = [col for col in binary_columns if col not in df.columns]
if missing_cols:
    raise KeyError(f"Columns missing from DataFrame: {missing_cols}")

# Take the first 2 observation vectors
obs1 = df.iloc[0]
obs2 = df.iloc[1]

# Extract binary attributes for both observations from the DataFrame
obs1_binary = df.loc[0, binary_columns]
obs2_binary = df.loc[1, binary_columns]

# Convert binary columns to 0/1 (assuming 't' is 1 and everything else is 0)
obs1_binary = obs1_binary.apply(lambda x: 1 if str(x).lower() == 't' else 0)
obs2_binary = obs2_binary.apply(lambda x: 1 if str(x).lower() == 't' else 0)

# Debugging: Print extracted binary attributes
print("obs1_binary:\n", obs1_binary)
print("obs2_binary:\n", obs2_binary)

# Calculate f11, f00, f01, and f10
f11 = np.sum((obs1_binary == 1) & (obs2_binary == 1))
f00 = np.sum((obs1_binary == 0) & (obs2_binary == 0))
f01 = np.sum((obs1_binary == 0) & (obs2_binary == 1))
f10 = np.sum((obs1_binary == 1) & (obs2_binary == 0))

# Debugging: Print values of f11, f00, f01, and f10
print(f"f11: {f11}, f00: {f00}, f01: {f01}, f10: {f10}")

# Compute Jaccard Coefficient (JC)
denominator_jc = f01 + f10 + f11
jc = f11 / denominator_jc if denominator_jc != 0 else np.nan

# Compute Simple Matching Coefficient (SMC)
denominator_smc = f00 + f01 + f10 + f11
smc = (f11 + f00) / denominator_smc if denominator_smc != 0 else np.nan

# Output the results
print(f"Jaccard Coefficient (JC): {jc}")
print(f"Simple Matching Coefficient (SMC): {smc}")
# Out:
# obs1_binary:
#  on thyroxine                 0
# query on thyroxine           0
# on antithyroid medication    0
# sick                         0
# pregnant                     0
# thyroid surgery              0
# I131 treatment               0
# query hypothyroid            1
# query hyperthyroid           0
# lithium                      0
# goitre                       0
# tumor                        0
# hypopituitary                0
# psych                        0
# TSH measured                 1
# Name: 0, dtype: int64
# obs2_binary:
#  on thyroxine                 0
# query on thyroxine           0
# on antithyroid medication    0
# sick                         0
# pregnant                     0
# thyroid surgery              0
# I131 treatment               0
# query hypothyroid            0
# query hyperthyroid           0
# lithium                      0
# goitre                       0
# tumor                        0
# hypopituitary                0
# ...

# %%
# A9 
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics.pairwise import cosine_similarity

# Load the data
df = pd.read_excel(r"C:\Users\Surya\OneDrive\Desktop\lab2\Lab Session Data.xlsx", sheet_name='thyroid0387_UCI')

# Replace missing values marked as '?'
df.replace('?', np.nan, inplace=True)

# Print column names to check for correct names
print("Column names in the DataFrame:", df.columns)

# Preprocess the data
# Convert categorical columns to numerical values using LabelEncoder
df_preprocessed = df.copy()

# Apply LabelEncoder to categorical columns
label_encoders = {}
for column in df_preprocessed.columns:
    if df_preprocessed[column].dtype == 'object':
        le = LabelEncoder()
        df_preprocessed[column] = df_preprocessed[column].astype(str)  # Ensure data is in string format
        df_preprocessed[column] = le.fit_transform(df_preprocessed[column])
        label_encoders[column] = le

# Handle missing values (e.g., replacing with 0 or mean)
for column in df_preprocessed.select_dtypes(include=[np.number]).columns:
    df_preprocessed[column].fillna(df_preprocessed[column].mean(), inplace=True)

# Take the complete vectors for the first two observations
obs1_complete = df_preprocessed.iloc[0].values.reshape(1, -1)
obs2_complete = df_preprocessed.iloc[1].values.reshape(1, -1)

# Calculate Cosine similarity
cosine_sim = cosine_similarity(obs1_complete, obs2_complete)[0][0]

print(f"Cosine Similarity: {cosine_sim}")
# Out:
# Column names in the DataFrame: Index(['Record ID', 'age', 'sex', 'on thyroxine', 'query on thyroxine',
#        'on antithyroid medication', 'sick', 'pregnant', 'thyroid surgery',
#        'I131 treatment', 'query hypothyroid', 'query hyperthyroid', 'lithium',
#        'goitre', 'tumor', 'hypopituitary', 'psych', 'TSH measured', 'TSH',
#        'T3 measured', 'T3', 'TT4 measured', 'TT4', 'T4U measured', 'T4U',
#        'FTI measured', 'FTI', 'TBG measured', 'TBG', 'referral source',
#        'Condition'],
#       dtype='object')
# Cosine Similarity: 0.9999999999999998
# C:\Users\Surya\AppData\Local\Temp\ipykernel_6520\3002097761.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace('?', np.nan, inplace=True)
# ...

# %%
#A10
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics.pairwise import cosine_similarity

# Load the dataset
file_path = r"C:\Users\Surya\OneDrive\Desktop\lab2\Lab Session Data.xlsx"
thyroid_data = pd.read_excel(file_path, sheet_name='thyroid0387_UCI')

# Replace '?' with NaN
thyroid_data.replace('?', np.nan)

# Initialize a dictionary to store label encoders for each categorical column
label_encoders_dict = {}

# Encode categorical variables and handle missing values
for cat_column in thyroid_data.select_dtypes(include=['object']).columns:
    if thyroid_data[cat_column].isnull().sum() > 0:
        thyroid_data[cat_column] = thyroid_data[cat_column].fillna(thyroid_data[cat_column].mode()[0])
    encoder = LabelEncoder()
    thyroid_data[cat_column] = encoder.fit_transform(thyroid_data[cat_column].astype(str))
    label_encoders_dict[cat_column] = encoder

# Handle missing values in numeric columns by filling with the mean
for num_column in thyroid_data.select_dtypes(include=[np.number]).columns:
    thyroid_data[num_column] = thyroid_data[num_column].fillna(thyroid_data[num_column].mean())

# Select the first 20 observation vectors
first_20_vectors = thyroid_data.iloc[:20]

# Initialize matrices to store JC, SMC, and COS values
n = len(first_20_vectors)
jc_matrix = np.zeros((n, n))
smc_matrix = np.zeros((n, n))
cos_matrix = np.zeros((n, n))

# Compute JC, SMC, and COS for each pair of vectors
for i in range(n):
    for j in range(n):
        if i != j:
            # Binary comparison for JC and SMC
            vec1 = first_20_vectors.iloc[i].astype(int)
            vec2 = first_20_vectors.iloc[j].astype(int)
            
            f11 = np.sum((vec1 == 1) & (vec2 == 1))
            f00 = np.sum((vec1 == 0) & (vec2 == 0))
            f10 = np.sum((vec1 == 1) & (vec2 == 0))
            f01 = np.sum((vec1 == 0) & (vec2 == 1))
            
            jc_matrix[i, j] = f11 / (f11 + f10 + f01) if (f11 + f10 + f01) != 0 else 0
            smc_matrix[i, j] = (f11 + f00) / (f11 + f00 + f10 + f01)
            
            # Cosine similarity
            cos_matrix[i, j] = cosine_similarity(vec1.values.reshape(1, -1), vec2.values.reshape(1, -1))[0][0]

# Plotting heatmaps for JC, SMC, and COS matrices
plt.figure(figsize=(18, 5))

plt.subplot(1, 3, 1)
sns.heatmap(jc_matrix, annot=True, cmap='viridis')
plt.title('Jaccard Coefficient (JC) Heatmap')

plt.subplot(1, 3, 2)
sns.heatmap(smc_matrix, annot=True, cmap='viridis')
plt.title('Simple Matching Coefficient (SMC) Heatmap')

plt.subplot(1, 3, 3)
sns.heatmap(cos_matrix, annot=True, cmap='viridis')
plt.title('Cosine Similarity (COS) Heatmap')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Surya\AppData\Local\Temp\ipykernel_6520\3554226095.py:13: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   thyroid_data.replace('?', np.nan)
